# %% [markdown]
# # Chess statistics

# %%
import chess
import numpy as np
import pandas as pd
import random

from tqdm import tqdm
from multiprocessing.pool import ThreadPool
import matplotlib.pyplot as plt

# %%
def collect_move_average_per_game(dummy) -> float:
    '''
    ADD
    '''
    moves = []
    board = chess.Board()
    
    while not (board.is_checkmate() or board.is_stalemate() or board.is_insufficient_material()):
        moves += [len([move for move in board.legal_moves])]
        move = random.choice([move for move in board.legal_moves])
        board.push(move)
    
    return np.mean(moves)

# %%
agg = []
for i in tqdm(range(1000)):
    res = ThreadPool(32).map(collect_move_average_per_game,[None for _ in range(10)])
    agg += [np.mean(res)]
np.mean(agg)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [06:51<00:00,  2.43it/s]
# 22.785660199358578

# %%
value = 0
games = 0
for _ in range(200):
    result = 1 if random.random() > 0.1 else 0
    games += 1
    value = value + ((result-value)/games)
value
# Out:
# 0.9100000000000001

# %%
# values = np.arange() 
# lambda loss

# %%
values = np.linspace(0,1,1000)

# %%
loss = lambda val, loss: val*0.9**loss

# %%
plt.plot(values)

# %%
fig = plt.figure()

x = np.linspace(0,1,1000)
loss = lambda val, loss: val*0.95**loss

plt.plot(x,x)
plt.plot(x,loss(x,1))
plt.plot(x,loss(x,2))
plt.plot(x,loss(x,3))
plt.plot(x,loss(x,4))
plt.plot(x,loss(x,5))
plt.plot(x,loss(x,6))
plt.plot(x,loss(x,7))

plt.show()
